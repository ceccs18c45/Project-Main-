# %%
import base64
from IPython.display import HTML

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("dataset covid.csv")

# %%
df.head(3)
# Out:
#    id                                              tweet label
# 0   1  Our daily update is published. States reported...  real
# 1   2             Alfalfa is the only cure for COVID-19.  fake
# 2   3  President Trump Asked What He Would Do If He W...  fake

# %%
df.shape
# Out:
# (2140, 3)

# %%
df['label'].value_counts()
# Out:
# real    1120
# fake    1020
# Name: label, dtype: int64

# %%
df = df.replace({'label': {'fake':"0"}})

# %%
df = df.replace({'label': {'real':"1"}})

# %%
df['label'].value_counts()
# Out:
# 1    1120
# 0    1020
# Name: label, dtype: int64

# %%
df.head(3)
# Out:
#    id                                              tweet label
# 0   1  Our daily update is published. States reported...     1
# 1   2             Alfalfa is the only cure for COVID-19.     0
# 2   3  President Trump Asked What He Would Do If He W...     0

# %%
def create_download_link( df, title = "Download CSV file", filename = "dataset covid.csv"):
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

# %%
create_download_link(df)
# Out:
# <a download="dataset covid.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>

# %%
df.drop(df[df['label'] == "0"].index, inplace=True)

# %%
df["label"].value_counts()
# Out:
# 1    1120
# Name: label, dtype: int64

# %%
df.head(3)
# Out:
#    id                                              tweet label
# 0   1  Our daily update is published. States reported...     1
# 3   4  States reported 630 deaths. We are still seein...     1
# 4   5  This is the sixth time a global health emergen...     1

# %%
def create_download_link( df, title = "Download CSV file", filename = "dataset covid.csv"):
    csv = df.to_csv()
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

# %%
create_download_link(df)
# Out:
# <a download="dataset covid.csv" href="data:text/csv;base64,..." target="_blank">Download CSV file</a>
